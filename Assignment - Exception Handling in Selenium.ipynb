# %% [markdown]
# AMAZON.IN

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.keys import Keys
import requests
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import time

# %%
driver = webdriver.Chrome()

# %%
driver.get(' https://www.amazon.in/')

# %%
A = str(input("Enter the product to be searched: "))

product = driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/div/input')
product.send_keys(A)
# Out:
# Enter the product to be searched: Earphones

# %%
search = driver.find_element(By.CLASS_NAME,"nav-right")
search.click()

# %% [markdown]
# AMAZON.IN - Continued...

# %%
Urls = []

start = 0
end = 2

for page in range(start,end):
    urls_tag = driver.find_elements(By.XPATH,'//h2[@class="a-size-mini a-spacing-none a-color-base s-line-clamp-2"]/a')
    for i in urls_tag:
        Urls.append(i.get_attribute('href'))
    
next_button = driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[1]/div[1]/div/span[1]/div[1]/div[31]/div/div/span/a[3]')
next_button.click()
time.sleep(5)

Urls
# Out:
# ['https://www.amazon.in/sspa/click?ie=UTF8&spc=MTo0NTg1MTQ1NTEzMDcxNzg4OjE3MjczMzU4Nzc6c3BfYXRmOjMwMDA0MTM2OTU4MzAzMjo6MDo6&url=%2FboAt-Launched-Airdopes-141-ANC%2Fdp%2FB0C7QS9M38%2Fref%3Dsr_1_1_sspa%3Fcrid%3D1CO1A95RG21PB%26dib%3DeyJ2IjoiMSJ9.HJAFnU3SJw9bn5ayGoOABz4T0CBv6CNJ4Ek_uvcTy0a__mZUn30vAVssEfxm1Kz3j7zRVGY6ibeT9qE27-UQOZFgdijyS7VGC20MebaBAJ1G8jDOLurX_BSW9BdD5tKatDqHxYhHKzLSTenFLVc5dsTrZ-5HjZme3NM5JceKX9PaDXPkYETp6SgOWwyW6vDCGDEkFQaybkATYh6FrKofI4RmNN9LWFutQrRM2azyZqk.7HaIdGnke0UD2iyGafBqzE1By6QEyUn_0YyZYc8RBZs%26dib_tag%3Dse%26keywords%3DEarphones%26qid%3D1727335877%26sprefix%3Dearphones%252Caps%252C448%26sr%3D8-1-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1',
# ...

# %%
Brand = []

for i in Url:
    driver.get(i)
    time.sleep(5)
    
    try:
        brand_tags = driver.find_element(By.XPATH,'//span[@class="a-size-base po-break-word"]')
        Brand.append(brand_tags.text)     
    except NoSuchElementException: 
        Brand.append('-')
        
Brand
# Out:
# ['boAt',
#  'amazon basics',
#  'boAt',
#  'ZEBRONICS',
#  'JBL',
#  'Lava',
#  'Mivi',
#  'Boult',
#  'Boult',
#  'Leaf',
#  'realme',
#  'boAt',
#  'boAt',
#  'ZEBRONICS',
#  'ZEBRONICS',
#  'boAt',
#  'Boult',
#  'boAt',
#  'Ambrane',
#  'boAt',
#  'boAt',
#  'ZEBRONICS',
#  'Portronics',
#  'boAt',
#  'Ambrane',
#  'Samsung',
#  'POLY',
#  'Boult',
#  'Mivi',
#  'pTron',
#  'amazon basics',
#  'Mivi',
#  'Leaf',
#  'boAt',
#  'amazon basics',
#  'boAt',
#  'ZEBRONICS',
#  'JBL',
#  'Lava',
#  'Mivi',
#  'Boult',
#  'Boult',
#  'Leaf',
#  'realme',
#  'boAt',
#  'boAt',
#  'ZEBRONICS',
#  'ZEBRONICS',
#  'boAt',
#  'Boult',
#  'boAt',
#  'Ambrane',
#  'boAt',
#  'boAt',
#  'ZEBRONICS',
#  'Portronics',
#  'boAt',
#  'Ambrane',
#  'Samsung',
#  'POLY',
#  'Boult',
#  'Mivi',
#  'pTron',
#  'amazon basics',
#  'Mivi',
#  'Leaf']

# %%
Product = []

for i in Url:
    driver.get(i)
    time.sleep(5)
    
    try:
        prd_tags = driver.find_element(By.XPATH,'//span[@class="a-size-large product-title-word-break"]')
        Product.append(prd_tags.text)     
    except NoSuchElementException: 
        Product.append('-')
        
Product
# Out:
# ['boAt Airdopes 141 ANC TWS in-Ear Earbuds w/ 32 dB ANC, 42 Hrs Playback, 50ms Low Latency Beast Mode, 4 Mics with ENx, ASAP Charge, IWP Twch with BT v5.3 & IPX5 Ear Buds TWS (Gunmetal Black)',
#  'amazon basics True Wireless in-Ear Earbuds with Mic, Touch Control, IPX5 Water-Resistance,Bluetooth 5.0, Up to 80 Hours Play Time, Voice Assistance&Fast Charging (Blue)',
#  'boAt BassHeads 100 in-Ear Wired Headphones with Mic (Black)',
#  'ZEBRONICS Zeb-Bro in Ear Wired Earphones with Mic, 3.5mm Audio Jack, 10mm Drivers, Phone/Tablet Compatible(Blue)',
#  'JBL C100SI Wired In Ear Headphones with Mic, JBL Pure Bass Sound, One Button Multi-function Remote, Premium Metallic Finish, Angled Buds for Comfort fit (Black)',
#  'Probuds N31 BT in-Ear Neckband (Firefly Green, 45+ hrs Playtime, ENC, Fast Charge (10min = 12hrs), IPX6 Rating, 10 mm Drivers, BT V5.3 Pro Game Mode (60ms Low Latency), and Dual Device Pairing)',
# ...

# %%
Price = []

for i in Url:
    driver.get(i)
    time.sleep(5)
    
    try:
        prce_tags = driver.find_element(By.XPATH,'//span[@class="a-price-whole"]')
        Price.append(prce_tags.text)     
    except NoSuchElementException: 
        Price.append('-')
        
Price
# Out:
# ['1,099',
#  '749',
#  '299',
#  '159',
#  '549',
#  '849',
#  '699',
#  '1,099',
#  '899',
#  '789',
#  '598',
#  '449',
#  '349',
#  '159',
#  '159',
#  '799',
#  '1,099',
#  '799',
#  '149',
#  '498',
#  '449',
#  '159',
#  '229',
#  '299',
#  '299',
#  '399',
#  '16,499',
#  '1,199',
#  '699',
#  '599',
#  '749',
#  '1,699',
#  '1,099',
#  '1,099',
#  '749',
#  '299',
#  '159',
#  '549',
#  '849',
#  '699',
#  '1,099',
#  '899',
#  '789',
#  '598',
#  '449',
#  '349',
#  '159',
#  '159',
#  '799',
#  '1,099',
#  '799',
#  '149',
#  '498',
#  '449',
#  '159',
#  '229',
#  '299',
#  '299',
#  '399',
#  '16,499',
#  '1,199',
#  '699',
#  '599',
#  '749',
#  '1,699',
#  '1,099']

# %%
Ret = []

for i in Url:
    driver.get(i)
    time.sleep(5)
    
    try:
        retn_tags = driver.find_element(By.XPATH,'//span[@class="a-size-small a-color-link a-text-normal"]')
        Ret.append(retn_tags.text)     
    except NoSuchElementException: 
        Ret.append('-')
        
Ret
# Out:
# ['7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Service Centre Replacement',
#  '7 days Service Centre Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Service Centre Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Service Centre Replacement',
#  '7 days Service Centre Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Service Centre Replacement',
#  '7 days Service Centre Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Service Centre Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Service Centre Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
# ...

# %%
Est = []

for i in Url:
    driver.get(i)
    time.sleep(5)
    
    try:
        est_tags = driver.find_element(By.XPATH,'//span[@class="a-text-bold"]')
        Est.append(est_tags.text)     
    except NoSuchElementException: 
        Est.append('-')
        
Est
# Out:
# ['Saturday, 28 September',
#  '',
#  'Saturday, 28 September',
#  '',
#  '',
#  'Saturday, 28 September',
#  '',
#  'Saturday, 28 September',
#  'Monday, 30 September',
#  '',
#  '',
#  'Saturday, 28 September',
#  'Saturday, 28 September',
#  '',
#  '',
#  'Saturday, 28 September',
#  'Saturday, 28 September',
#  'Saturday, 28 September',
#  '',
#  'Saturday, 28 September',
#  'Saturday, 28 September',
#  '',
#  '',
#  'Saturday, 28 September',
#  '',
#  'Saturday, 28 September',
#  '',
#  'Saturday, 28 September',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Saturday, 28 September',
#  '',
#  'Saturday, 28 September',
#  '',
#  '',
#  'Saturday, 28 September',
#  '',
#  'Saturday, 28 September',
#  'Monday, 30 September',
#  '',
#  '',
#  'Saturday, 28 September',
#  'Saturday, 28 September',
#  '',
#  '',
#  'Saturday, 28 September',
#  'Saturday, 28 September',
#  'Saturday, 28 September',
#  '',
#  'Saturday, 28 September',
#  'Saturday, 28 September',
#  '',
#  '',
# ...

# %%
Availability = []

for i in Url:
    driver.get(i)
    time.sleep(5)
    
    try:
        avl_tags = driver.find_element(By.XPATH,'//span[@class="a-size-medium a-color-success"]')
        Availability.append(avl_tags.text)     
    except NoSuchElementException: 
        Availability.append('-')
        
Availability
# Out:
# ['In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock']

# %%
len(Product),len(Brand),len(Price),len(Ret),len(Est),len(Availability),len(Url)
# Out:
# (66, 66, 66, 66, 66, 66, 66)

# %%
df = pd.DataFrame({"Product Name":Product,"Brand":Brand,"Price":Price,"Return/Exchange":Ret,"Estimated Delivery Date":Est,"Availability":Availability,"Link":Url})
df
# Out:
#                                          Product Name          Brand  Price  \
# 0   boAt Airdopes 141 ANC TWS in-Ear Earbuds w/ 32...           boAt  1,099
# 1   amazon basics True Wireless in-Ear Earbuds wit...  amazon basics    749
# 2   boAt BassHeads 100 in-Ear Wired Headphones wit...           boAt    299
# 3   ZEBRONICS Zeb-Bro in Ear Wired Earphones with ...      ZEBRONICS    159
# 4   JBL C100SI Wired In Ear Headphones with Mic, J...            JBL    549
# ..                                                ...            ...    ...
# 61  Mivi DuoPods i2 True Wireless Earbuds, 45+ Hrs...           Mivi    699
# 62  pTron Bassbuds NX in-Ear TWS Earbuds, TruTalk ...          pTron    599
# 63  amazon basics True Wireless in-Ear Earbuds wit...  amazon basics    749
# 64  Mivi SuperPods Dueto, True Wireless Earbuds, D...           Mivi  1,699
# 65  Leaf Buds X614 True Wireless ANC in Ear Earbud...           Leaf  1,099
#
# ...

# %%
df.to_csv("Desktop\Exported_file.csv")

# %%
pd.read_csv("Desktop\Exported_file.csv")
# Out:
#     Unnamed: 0                                       Product Name  \
# 0            0  boAt Airdopes 141 ANC TWS in-Ear Earbuds w/ 32...
# 1            1  amazon basics True Wireless in-Ear Earbuds wit...
# 2            2  boAt BassHeads 100 in-Ear Wired Headphones wit...
# 3            3  ZEBRONICS Zeb-Bro in Ear Wired Earphones with ...
# 4            4  JBL C100SI Wired In Ear Headphones with Mic, J...
# ..         ...                                                ...
# 61          61  Mivi DuoPods i2 True Wireless Earbuds, 45+ Hrs...
# 62          62  pTron Bassbuds NX in-Ear TWS Earbuds, TruTalk ...
# 63          63  amazon basics True Wireless in-Ear Earbuds wit...
# 64          64  Mivi SuperPods Dueto, True Wireless Earbuds, D...
# 65          65  Leaf Buds X614 True Wireless ANC in Ear Earbud...
#
#             Brand  Price                    Return/Exchange  \
# 0            boAt  1,099                 7 days Replacement
# ...

# %% [markdown]
# IMAGES.GOOGLE.COM

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://images.google.com/')

# %%
Picture = str(input('Enter the image to be searched for: '))

img = driver.find_element(By.CLASS_NAME,"gLFyf")
img.send_keys(Picture)
# Out:
# Enter the image to be searched for: Cakes

# %%
search = driver.find_element(By.CLASS_NAME,"zgAlFc")
search.click()

# %%
Images_of_Cakes = []

img5 = driver.find_elements(By.CLASS_NAME,"YQ4gaf")

for i in img5:
    Images_of_Cakes.append(i.get_attribute('src'))

# %%
Cakes_Img = Images_of_Cakes[0:10]

# %%
Cakes_Img
# Out:
# ['data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQiiKyHwMDx2Ry8do1Z2WIGnmi07NmU00_5MNZDUuNA6F4rl6vZI5LxJwog&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQx6aeGP5uWOorBZniwEcBTBupPPJhKud3LFTvQ6qJR7BT7nGLkrxl68k6s&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRAsz6j62Cg6wb5TWs9Zb04N5cWC1P7JwKCmTLanFS2VRi9x0yDQq2xz9D_&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR3KWAWy6b4EV02HyY4WNTnnyjBVW73pPh9i0aAG6STtkZM_3pMmZ42kUtw&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQvTxFh1LMTGA_EzYpBtEzA5nKy2SDyKFbcqqHiN0YMcavHzWpoFXGAMJ1V&s']

# %%
Images_of_Guitars = []

img4 = driver.find_elements(By.CLASS_NAME,"YQ4gaf")

for i in img4:
    Images_of_Guitars.append(i.get_attribute('src'))

# %%
Guitars_Img = Images_of_Guitars[0:10]

# %%
Guitars_Img
# Out:
# ['data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQU7SizQ0o2gPtU0sMIXfFEBd14YQy1Mnj-mwQ7ubYkvAFkX8YHhlXVBmp9&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT08Y7DFyg8i08ZvYo1ZdbYnf9o3-c3RRHNeCWlxL_iB-9hTfA0OppEtUYV&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQerg2qqU3qHDlwR8YP-GnI5nnwqUaF8wIaF2oTuFrfqHJKK01zTzfWMEj3&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQxQl1hVvi6wJKkmMActqrPZWfbWwuzRcSwpPF2evs0xzcSeRBaUIuyXVKQ&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQHLQjDlvgDeTV81fXAlOjk_5BD5svG9v_rPvBahMuEqmhu-4bXBHQEr755&s']

# %%
Images_of_ML = []

img3 = driver.find_elements(By.CLASS_NAME,"YQ4gaf")

for i in img3:
    Images_of_ML.append(i.get_attribute('src'))

# %%
ML_Img = Images_of_ML[0:10]

# %%
ML_Img
# Out:
# ['data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/png;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  '...',
#  'data:image/jpeg;base64,...',
#  '...',
#  'data:image/jpeg;base64,...']

# %%
Images_of_Cars = []

img2 = driver.find_elements(By.CLASS_NAME,"YQ4gaf")

for i in img2:
    Images_of_Cars.append(i.get_attribute('src'))

# %%
Cars_Img = Images_of_Cars[0:10]

# %%
Cars_Img
# Out:
# ['data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTdljmVRja9WQdPLzLB2wzqbCoV5KabEwPav9-uUEPVGkWARSSSz0H665VJ&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSpVIq5GB6zeuj2X033Gpfud0t4EUrpPWpOvX009x43e2-3Qr-bfLitUTLM&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSX5BtQTLYSFBS9dskWiO4dvXSamth9jKtuj_e5Z7P7hxtIqnZznt98xSt7&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT8iHc67zA4K2ETsLnfA1JmTfLrKAv23DdSx_Kn4giiIJSPXq_FmmnY74py&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRRUgs-KxZZCxC9IYGWbSak8PD5RnsQ_D0g3vuRTRMKZkmC6nSF4SB3a4cb&s']

# %%
Images_of_Fruits = []

img1 = driver.find_elements(By.CLASS_NAME,"YQ4gaf")

for i in img1:
    Images_of_Fruits.append(i.get_attribute('src'))

# %%
Fruits_Img = Images_of_Fruits[0:10]

# %%
Fruits_Img
# Out:
# ['data:image/png;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSfXdjbHBJX06KUKN4tkfd8KFFDyYnIICCvDxYxgY3_0Plx7p71-aCeB-fp&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQqYJBok224Z-DbeBD_5CwlcXe4lzqf6qeArNGfvdGiWjggxyUvLTL8nXYg&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQhRe8IDwbhaqr66uyVbS3Mcn8qLL5bqhVNrKr19LhFvDtTE3wmthx8m3Zx&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQJI-r9JDFn4sJnHXt76kL8lBBybGhtbRz3ArtMtSSGdocJlaSoA2sZPze4&s',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ7_oUcpRcockTx1Ais7ZEkPKNbuhkldMznwcvnpM_2lrMY3VT24jmALvxQ&s']

# %%
len(Fruits_Img),len(Cars_Img),len(ML_Img),len(Guitars_Img),len(Cakes_Img)
# Out:
# (10, 10, 10, 10, 10)

# %% [markdown]
# FLIPKART.COM

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.keys import Keys
import requests
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import time

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://www.flipkart.com/')

# %%
Phone  = str(input('Enter the phone to be searched: '))

products = driver.find_element(By.CLASS_NAME,"Pke_EE")
products.send_keys(Phone)
# Out:
# Enter the phone to be searched: Oneplus Nord Smartphone

# %%
search = driver.find_element(By.CLASS_NAME,"_2iLD__")
search.click()

# %%
URL123 = []

url123_tag = driver.find_elements(By.XPATH,'//a[@class="CGtC98"]')
for i in url123_tag:
    URL123.append(i.get_attribute("href"))

# %%
URL123
# Out:
# ['https://www.flipkart.com/oneplus-nord-gray-onyx-128-gb/p/itm3f93c90430130?pid=MOBFUE5HW4XUUGBN&lid=LSTMOBFUE5HW4XUUGBNCW8SRR&marketplace=FLIPKART&q=Oneplus+Nord+Smartphone&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=cf435c30-4146-4714-8571-cb55d1128ae8.MOBFUE5HW4XUUGBN.SEARCH&ppt=hp&ppn=homepage&ssid=ejkmgiyo280000001727291099488&qH=eb3364097f3c411f',
#  'https://www.flipkart.com/oneplus-nord-gray-onyx-256-gb/p/itm3f93c90430130?pid=MOBFUE5GGWHFC37J&lid=LSTMOBFUE5GGWHFC37J9T5PNY&marketplace=FLIPKART&q=Oneplus+Nord+Smartphone&store=tyy%2F4io&srno=s_1_2&otracker=search&otracker1=search&fm=organic&iid=cf435c30-4146-4714-8571-cb55d1128ae8.MOBFUE5GGWHFC37J.SEARCH&ppt=hp&ppn=homepage&ssid=ejkmgiyo280000001727291099488&qH=eb3364097f3c411f',
# ...

# %%
len(URL123)
# Out:
# 24

# %%
Colour = []

for i in URL123:
    driver.get(i)
    time.sleep(5)
    
    try:
        col_tags = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[4]/div/div[2]/div[1]/div[1]/table/tbody/tr[4]/td[2]/ul/li')
        Colour.append(col_tags.text)     
    except NoSuchElementException: 
        Colour.append('-')
        
Colour
# Out:
# ['Gray Onyx',
#  'Gray Onyx',
#  '-',
#  'Chromatic Gray',
#  'Pastel Lime',
#  'Chromatic Gray',
#  'MEGA BLUE',
#  'ULTRA ORANGE',
#  '-',
#  'Dark Chrome',
#  '-',
#  'Celadon Marble',
#  'Celadon Marble',
#  'ULTRA ORANGE',
#  'SUPER SILVER',
#  'Blue Tide',
#  'Aqua Surge',
#  'SUPER SILVER',
#  'MEGA BLUE',
#  'Grey Shimmer',
#  'Tempest Gray',
#  'Misty Green',
#  'Misty Green',
#  'Tempest Gray']

# %%
Brand_Name = []

for i in URL123:
    driver.get(i)
    time.sleep(5)
    
    try:
        brd_tags = driver.find_element(By.XPATH,'//a[@class="R0cyWM"]')
        Brand_Name.append(brd_tags.text.replace('Home','Oneplus'))     
    except NoSuchElementException: 
        Brand_Name.append('-')
        
Brand_Name
# Out:
# ['Oneplus',
#  'Oneplus',
#  'Oneplus',
#  'Oneplus',
#  '-',
#  'Oneplus',
#  'Oneplus',
#  'Oneplus',
#  'Oneplus',
#  'Oneplus',
#  'Oneplus',
#  'Oneplus',
#  'Oneplus',
#  'Oneplus',
#  'Oneplus',
#  'Oneplus',
#  'Oneplus',
#  'Oneplus',
#  'Oneplus',
#  'Oneplus',
#  'Oneplus',
#  'Oneplus',
#  'Oneplus',
#  'Oneplus']

# %%
Smartphone = []

for i in URL123:
    driver.get(i)
    time.sleep(5)
    
    try:
        phone_tags = driver.find_element(By.XPATH,'//span[@class="VU-ZEz"]')
        Smartphone.append(phone_tags.text)     
    except NoSuchElementException: 
        Smartphone.append('-')
        
Smartphone
# Out:
# ['OnePlus Nord (Gray Onyx, 128 GB)  (8 GB RAM)',
#  'OnePlus Nord (Gray Onyx, 256 GB)  (12 GB RAM)',
#  'OnePlus Nord CE 3 Lite 5G (Pastel Lime, 256 GB)  (8 GB RAM)',
#  'OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 128 GB)  (8 GB RAM)',
#  'OnePlus Nord CE 3 Lite 5G (Pastel Lime, 128 GB)  (8 GB RAM)',
#  'OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 256 GB)  (8 GB RAM)',
#  'OnePlus Nord CE4 lite 5G (MEGA BLUE, 256 GB)  (8 GB RAM)',
#  'OnePlus Nord CE4 lite 5G (ULTRA ORANGE, 128 GB)  (8 GB RAM)',
#  'OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)  (6 GB RAM)',
#  'OnePlus Nord CE4 (Dark Chrome, 256 GB)  (8 GB RAM)',
#  'OnePlus Nord CE4 (Dark Chrome, 128 GB)  (8 GB RAM)',
#  'OnePlus Nord CE4 (Celadon Marble, 256 GB)  (8 GB RAM)',
#  'OnePlus Nord CE4 (Celadon Marble, 128 GB)  (8 GB RAM)',
#  'OnePlus Nord CE4 lite 5G (ULTRA ORANGE, 256 GB)  (8 GB RAM)',
#  'OnePlus Nord CE4 lite 5G (SUPER SILVER, 128 GB)  (8 GB RAM)',
#  'OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)  (6 GB RAM)',
# ...

# %%
RAM = []

for i in URL123:
    driver.get(i)
    time.sleep(5)
    
    try:
        ram_tags = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[4]/div/div[2]/div[1]/div[4]/table/tbody/tr[2]/td[2]')
        RAM.append(ram_tags.text)     
    except NoSuchElementException: 
        RAM.append('-')
        
RAM
# Out:
# ['',
#  '',
#  '-',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '-',
#  '',
#  '-',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
ROM = []

for i in URL123:
    driver.get(i)
    time.sleep(5)
    
    try:
        rom_tags = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[4]/div/div[2]/div[1]/div[4]/table/tbody/tr[1]/td[2]/ul/li')
        ROM.append(rom_tags.text)     
    except NoSuchElementException: 
        ROM.append('-')
        
ROM
# Out:
# ['',
#  '',
#  '-',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '-',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
Camera1 = []

for i in URL123:
    driver.get(i)
    time.sleep(5)
    
    try:
        cam1_tags = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[4]/div/div[2]/div[1]/div[5]/table/tbody/tr[2]/td[2]/ul/li')
        Camera1.append(cam1_tags.text)     
    except NoSuchElementException: 
        Camera1.append('-')
        
Camera1
# Out:
# ['',
#  '',
#  '-',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '-',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
Camera2 = []

for i in URL123:
    driver.get(i)
    time.sleep(5)
    
    try:
        cam2_tags = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[4]/div/div[2]/div[1]/div[5]/table/tbody/tr[6]/td[2]/ul/li')
        Camera2.append(cam2_tags.text)     
    except NoSuchElementException: 
        Camera2.append('-')
        
Camera2
# Out:
# ['',
#  '',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '',
#  '',
#  '',
#  '',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '']

# %%
Display = []

for i in URL123:
    driver.get(i)
    time.sleep(5)
    
    try:
        dsp_tags = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div[5]/div/div[2]/div[1]/div[2]/table/tbody/tr[1]/td[2]/ul/li')
        Display.append(dsp_tags.text)     
    except NoSuchElementException: 
        Display.append('-')
        
Display
# Out:
# ['-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-']

# %%
Battery = []

for i in URL123:
    driver.get(i)
    time.sleep(5)
    
    try:
        btry_tags = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[4]/div/div[2]/div[1]/div[10]/table/tbody/tr[1]/td[2]/ul/li')
        Battery.append(btry_tags.text)     
    except NoSuchElementException: 
        Battery.append('-')
        
Battery
# Out:
# ['',
#  '',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '',
#  '',
#  '',
#  '',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '']

# %%
Amount = []

for i in URL123:
    driver.get(i)
    time.sleep(5)
    
    try:
        amt_tags = driver.find_element(By.XPATH,'//div[@class="Nx9bqj CxhGGd"]')
        Amount.append(amt_tags.text)     
    except NoSuchElementException: 
        Amount.append('-')
        
Amount
# Out:
# ['₹26,990',
#  '₹28,799',
#  '₹17,620',
#  '₹16,076',
#  '₹16,076',
#  '₹18,900',
#  '₹21,760',
#  '₹20,390',
#  '₹17,488',
#  '₹26,880',
#  '₹24,349',
#  '₹26,848',
#  '₹24,890',
#  '₹22,478',
#  '₹20,388',
#  '₹18,999',
#  '₹19,188',
#  '₹20,990',
#  '₹19,787',
#  '₹18,777',
#  '₹37,490',
#  '₹24,967',
#  '₹35,999',
#  '₹33,999']

# %%
len(Smartphone),len(Brand_Name),len(Colour),len(RAM),len(ROM),len(Camera1),len(Camera2),len(Display),len(Battery),len(Amount),len(URL123)
# Out:
# (24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24)

# %%
df = pd.DataFrame({"Smartphone Name":Smartphone,"Brand Name":Brand_Name,"Colour":Colour,"RAM":RAM,"Storage(ROM)":ROM,"Primary Camera":Camera1,"Secondary Camera":Camera2,"Display Size":Display,"Battery Capacity":Battery,"Price":Amount,"Link":URL123})
df
# Out:
#                                       Smartphone Name Brand Name  \
# 0        OnePlus Nord (Gray Onyx, 128 GB)  (8 GB RAM)    Oneplus
# 1       OnePlus Nord (Gray Onyx, 256 GB)  (12 GB RAM)    Oneplus
# 2   OnePlus Nord CE 3 Lite 5G (Pastel Lime, 256 GB...    Oneplus
# 3   OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 128...    Oneplus
# 4   OnePlus Nord CE 3 Lite 5G (Pastel Lime, 128 GB...          -
# 5   OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 256...    Oneplus
# 6   OnePlus Nord CE4 lite 5G (MEGA BLUE, 256 GB)  ...    Oneplus
# 7   OnePlus Nord CE4 lite 5G (ULTRA ORANGE, 128 GB...    Oneplus
# 8   OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)...    Oneplus
# 9   OnePlus Nord CE4 (Dark Chrome, 256 GB)  (8 GB ...    Oneplus
# 10  OnePlus Nord CE4 (Dark Chrome, 128 GB)  (8 GB ...    Oneplus
# 11  OnePlus Nord CE4 (Celadon Marble, 256 GB)  (8 ...    Oneplus
# 12  OnePlus Nord CE4 (Celadon Marble, 128 GB)  (8 ...    Oneplus
# ...

# %%
df.to_csv("Desktop\Exported_file1.csv")

# %%
pd.read_csv("Desktop\Exported_file1.csv")
# Out:
#     Unnamed: 0                                    Smartphone Name Brand Name  \
# 0            0       OnePlus Nord (Gray Onyx, 128 GB)  (8 GB RAM)    Oneplus
# 1            1      OnePlus Nord (Gray Onyx, 256 GB)  (12 GB RAM)    Oneplus
# 2            2  OnePlus Nord CE 3 Lite 5G (Pastel Lime, 256 GB...    Oneplus
# 3            3  OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 128...    Oneplus
# 4            4  OnePlus Nord CE 3 Lite 5G (Pastel Lime, 128 GB...          -
# 5            5  OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 256...    Oneplus
# 6            6  OnePlus Nord CE4 lite 5G (MEGA BLUE, 256 GB)  ...    Oneplus
# 7            7  OnePlus Nord CE4 lite 5G (ULTRA ORANGE, 128 GB...    Oneplus
# 8            8  OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)...    Oneplus
# 9            9  OnePlus Nord CE4 (Dark Chrome, 256 GB)  (8 GB ...    Oneplus
# 10          10  OnePlus Nord CE4 (Dark Chrome, 128 GB)  (8 GB ...    Oneplus
# ...

# %% [markdown]
# GOOGLE MAPS

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://www.google.com/maps')

# %%
City = str(input('Enter the city to be searched for: '))

ct_tag = driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/div[8]/div[3]/div[1]/div[1]/div/div[1]/form/input')
ct_tag.send_keys(City)
# Out:
# Enter the city to be searched for: Pune

# %%
search = driver.find_element(By.CLASS_NAME,"pzfvzf")
search.click()

# %% [markdown]
# DIGIT.IN

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://www.digit.in/')

# %%
lap = driver.find_element(By.CLASS_NAME,"re-ajax-search")
lap.send_keys('Gaming Laptops')

# %%
search = driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div/div/div[2]/form/button')
search.click()

# %%
Link = []

link_tags = driver.find_elements(By.XPATH,'//a[@class="img-centered-flex rh-flex-justify-center rh-flex-center-align"]')
for i in link_tags:
    Link.append(i.get_attribute("href"))

# %%
Link
# Out:
# ['https://www.digit.in/laptops/lenovo-ideapad-gaming-3-15iah7-price-341574.html',
#  'https://www.digit.in/laptops/lenovo-ideapad-gaming-3i-price-319434.html',
#  'https://www.digit.in/laptops/alienware-x14-gaming-laptop-price-318804.html',
#  'https://www.digit.in/laptops/msi-gaming-raider-ge76-12th-gen-core-i9-12900hk-2022-price-287791.html',
#  'https://www.digit.in/laptops/lenovo-legion-7-ryzen-9-5900hx-2022-price-288225.html',
#  'https://www.digit.in/laptops/dell-15-2021-i5-10200h-price-287917.html']

# %%
Laptop_Name = []

for i in Link:
    driver.get(i)
    time.sleep(5)
    
    try:
        name_tags = driver.find_element(By.XPATH,'//h1[@class="floatleft tabletblockdisplay pr20 "]')
        Laptop_Name.append(name_tags.text)     
    except NoSuchElementException: 
        Laptop_Name.append('-')

# %%
Laptop_Name
# Out:
# ['Lenovo IdeaPad Gaming 3 15IAH7',
#  'Lenovo IdeaPad Gaming 3i',
#  'Alienware x14 Gaming Laptop',
#  'MSI Gaming Raider',
#  'Lenovo Legion 7',
#  'Dell 15 (2021) i5-10200H']

# %%
Processor = []

for i in Link:
    driver.get(i)
    time.sleep(5)
    
    try:
        proc_tags = driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/div[1]/div/div/div/div/div[2]/div[1]/div[4]/div[3]/div[1]/div/ul/li[2]/div/p[2]/strong')
        Processor.append(proc_tags.text)     
    except NoSuchElementException: 
        Processor.append('-')

# %%
Processor
# Out:
# ['-',
#  '10th Gen Intel Core I5-10300H',
#  '-',
#  '-',
#  '-',
#  '10th Gen Intel Core I5-10200H']

# %%
Display = []

for i in Link:
    driver.get(i)
    time.sleep(5)
    
    try:
        dis_tags = driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/div/div/div/div/div[2]/div[1]/div[4]/div[3]/div/div/ul/li[4]/div/p[2]')
        Display.append(dis_tags.text)     
    except NoSuchElementException: 
        Display.append('-')

# %%
Display
# Out:
# ['-', '-', '-', '-', '16', '-']

# %%
Storage = []

for i in Link:
    driver.get(i)
    time.sleep(5)
    
    try:
        stor_tags = driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/div[1]/div/div/div/div/div[2]/div[4]/div[3]/div[2]/table/tbody/tr[14]/td/table/tbody/tr[1]/td')
        Storage.append(stor_tags.text)     
    except NoSuchElementException: 
        Storage.append('-')

# %%
Storage
# Out:
# ['-', '512 GB', '-', '-', '-', '512 GB']

# %%
/html/body/div[1]/div[3]/div[1]/div/div/div/div/div[2]/div[1]/div[4]/div[3]/div[1]/div/ul/li[3]/div

# %%
Graphics = []

for i in Link:
    driver.get(i)
    time.sleep(5)
    
    try:
        graph_tags = driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/div[1]/div/div/div/div/div[2]/div[4]/div[3]/div[2]/table/tbody/tr[12]/td/table/tbody/tr[5]/td')
        Graphics.append(graph_tags.text)     
    except NoSuchElementException: 
        Graphics.append('-')

# %%
Graphics
# Out:
# ['-', 'NVIDIA GeForce GTX 1650 Ti', '-', '-', '-', 'NVIDIA GeForce GTX 1650']

# %%
RAM = []

for i in Link:
    driver.get(i)
    time.sleep(5)
    
    try:
        ram_tags = driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/div[1]/div/div/div/div/div[2]/div[4]/div[3]/div[2]/table/tbody/tr[8]/td/table/tbody/tr[1]/td')
        RAM.append(ram_tags.text)     
    except NoSuchElementException: 
        RAM.append('-')

# %%
RAM
# Out:
# ['-', '8 GB', '-', '-', '-', '16 GB']

# %%
df = pd.DataFrame({"Laptop Name":Laptop_Name,"Processor":Processor,"Display(In Inches)":Display,"Storage(ROM)":Storage,"RAM":RAM,"Graphics":Graphics,"Links":Link})
df
# Out:
#                       Laptop Name                      Processor  \
# 0  Lenovo IdeaPad Gaming 3 15IAH7                              -
# 1        Lenovo IdeaPad Gaming 3i  10th Gen Intel Core I5-10300H
# 2     Alienware x14 Gaming Laptop                              -
# 3               MSI Gaming Raider                              -
# 4                 Lenovo Legion 7                              -
# 5        Dell 15 (2021) i5-10200H  10th Gen Intel Core I5-10200H
#
#   Display(In Inches) Storage(ROM)    RAM                    Graphics  \
# 0                  -            -      -                           -
# 1                  -       512 GB   8 GB  NVIDIA GeForce GTX 1650 Ti
# 2                  -            -      -                           -
# 3                  -            -      -                           -
# 4                 16            -      -                           -
# 5                  -       512 GB  16 GB     NVIDIA GeForce GTX 1650
#
# ...

# %% [markdown]
# FORBES.COM

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://www.forbes.com/')

# %%
ham = driver.find_element(By.CLASS_NAME,"USVF4LaM")
ham.click()

# %%
dropdown = driver.find_element(By.XPATH,'/html/body/div[1]/header/div/header/div[1]/div[1]/div[2]/ul/li[2]/div[1]/span')
dropdown.click()

# %%
option = driver.find_element(By.XPATH,'/html/body/div[1]/header/div/header/div[1]/div[1]/div[2]/ul/li[2]/div[2]/div[3]/ul/li[1]/a')
option.click()

# %%
Ranking = []

start = 0
end = 14

for page in range(start,end):
    ranking_tags = driver.find_elements(By.XPATH,'//div[@class="Table_rank__X4MKf"]/div')
    for i in ranking_tags:
        Ranking.append(i.text)
        
    next_button = driver.find_elements(By.XPATH,'/html/body/div[1]/div[2]/div/div/div[3]/div[2]/div[2]/div/div[2]/div[27]/div[7]/div[1]/nav/div/button[7]')

# %%
len(Ranking)
# Out:
# 2800

# %%
B_Name = []

start = 0
end = 14

for page in range(start,end):
    bname_tags = driver.find_elements(By.XPATH,'//div[@class="Table_personName__Bus2E"]')
    for i in bname_tags:
        B_Name.append(i.text)
        
    next_button = driver.find_elements(By.XPATH,'/html/body/div[1]/div[2]/div/div/div[3]/div[2]/div[2]/div/div[2]/div[27]/div[7]/div[1]/nav/div/button[7]')

# %%
len(B_Name)
# Out:
# 2800

# %%
Networth = []

start = 0
end = 14

for page in range(start,end):
    worth_tags = driver.find_elements(By.XPATH,'//div[@class="Table_finalWorth__UZA6k"]')
    for i in worth_tags:
        Networth.append(i.text)
        
    next_button = driver.find_elements(By.XPATH,'/html/body/div[1]/div[2]/div/div/div[3]/div[2]/div[2]/div/div[2]/div[27]/div[7]/div[1]/nav/div/button[7]')

# %%
len(Networth)
# Out:
# 2800

# %%
Age = []

start = 0
end = 14

for page in range(start,end):
    age_tags = driver.find_elements(By.XPATH,'/html/body/div[1]/div[2]/div/div/div[3]/div[2]/div[2]/div/div[2]/div[1]/div[2]/div[4]/div')
    for i in age_tags:
        Age.append(i.text)
        
    next_button = driver.find_elements(By.XPATH,'/html/body/div[1]/div[2]/div/div/div[3]/div[2]/div[2]/div/div[2]/div[27]/div[7]/div[1]/nav/div/button[7]')

# %%
len(Age)
# Out:
# 14

# %%
Place = []

start = 0
end = 14

for page in range(start,end):
    place_tags = driver.find_elements(By.XPATH,'/html/body/div[1]/div[2]/div/div/div[3]/div[2]/div[2]/div/div[2]/div[1]/div[2]/div[5]')
    for i in place_tags:
        Place.append(i.text)
        
    next_button = driver.find_elements(By.XPATH,'/html/body/div[1]/div[2]/div/div/div[3]/div[2]/div[2]/div/div[2]/div[27]/div[7]/div[1]/nav/div/button[7]')

# %%
len(Place)
# Out:
# 14

# %%
Source = []

start = 0
end = 14

for page in range(start,end):
    source_tags = driver.find_elements(By.XPATH,'/html/body/div[1]/div[2]/div/div/div[3]/div[2]/div[2]/div/div[2]/div[1]/div[2]/div[6]')
    for i in source_tags:
        Source.append(i.text)
        
    next_button = driver.find_elements(By.XPATH,'/html/body/div[1]/div[2]/div/div/div[3]/div[2]/div[2]/div/div[2]/div[27]/div[7]/div[1]/nav/div/button[7]')

# %%
len(Source)
# Out:
# 14

# %%
Industry = []

start = 0
end = 14

for page in range(start,end):
    inds_tags = driver.find_elements(By.XPATH,'/html/body/div[1]/div[2]/div/div/div[3]/div[2]/div[2]/div/div[2]/div[1]/div[2]/div[7]')
    for i in inds_tags:
        Industry.append(i.text)
        
    next_button = driver.find_elements(By.XPATH,'/html/body/div[1]/div[2]/div/div/div[3]/div[2]/div[2]/div/div[2]/div[27]/div[7]/div[1]/nav/div/button[7]')

# %%
len(Industry)
# Out:
# 14

# %%
df = pd.DataFrame({"Rank":Ranking,"Name":B_Name,"Net Worth":Networth})
df
# Out:
#       Rank                             Name Net Worth
# 0       1.         Bernard Arnault & family    $233 B
# 1       2.                        Elon Musk    $195 B
# 2       3.                       Jeff Bezos    $194 B
# 3       4.                  Mark Zuckerberg    $177 B
# 4       5.                    Larry Ellison    $141 B
# ...    ...                              ...       ...
# 2795  195.                          Lei Jun   $10.9 B
# 2796  195.                 Georg Schaeffler   $10.9 B
# 2797  195.  Marcel Herrmann Telles & family   $10.9 B
# 2798  199.             David Velez & family   $10.8 B
# 2799  200.        Suleiman Kerimov & family   $10.7 B
#
# [2800 rows x 3 columns]

# %% [markdown]
# YOUTUBE.COM

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://www.youtube.com/')

# %%
C = str(input('Video to be searched: '))

video = driver.find_element(By.CLASS_NAME,"style-scope ytd-searchbox")
video.send_keys(C)
# Out:
# Video to be searched: Kiara Advani Wedding

# %%
search = driver.find_element(By.XPATH,'/html/body/ytd-app/div[1]/div/ytd-masthead/div[4]/div[2]/ytd-searchbox/button')
search.click()

# %%
url = driver.find_element(By.XPATH,'/html/body/ytd-app/div[1]/ytd-page-manager/ytd-search/div[1]/ytd-two-column-search-results-renderer/div/ytd-section-list-renderer/div[2]/ytd-item-section-renderer/div[3]/ytd-video-renderer[1]/div[1]/div/div[1]/div/h3/a')
url.click()

# %%
Comments = []

start = 0
end = 24

for page in range(start,end):
    comment_tag = driver.find_elements(By.XPATH,'//div[@class="style-scope ytd-expander"]')
    for i in comment_tag:
        Comments.append(i.text)
    
Comments
# Out:
# ["The way Kiara appreciated Sid's looks. Usually grooms appreciates their brides who takes the center stage, but Kiara was so happy that she couldn't control it and put Sid before her. What a colourful happy bride she is️. God bless them. I can watch this all day",
#  'I have always felt the OG version was a wedding song (despite being rebutted that it was a sad song). Absolutely love how this alternate version has been made for their wedding. So genuine and beautiful.',
#  'After watching this video it felt like Shershaah finally got the right climax. Best wishes to Sid and Kiara ',
#  "That sound of kaleeras while she's walking deserves a special mention and applause. Take a bow team Wedding Filmer. Beauty in simplicity will be defined by this clip now onwards.",
# ...

# %%
Time = []

start = 0
end = 24

for page in range(start,end):
    time_tag = driver.find_elements(By.XPATH,'//span[@class="style-scope ytd-comment-view-model"]')
    for i in time_tag:
        Time.append(i.text)
    
Time
# Out:
# ['',
#  '',
#  '1 year ago',
#  '',
#  '',
#  '1 year ago',
#  '',
#  '',
#  '1 year ago',
#  '',
#  '',
#  '1 year ago',
#  '',
#  '',
#  '1 year ago',
#  '',
#  '',
#  '1 year ago',
#  '',
#  '',
#  '1 year ago',
#  '',
#  '',
#  '6 months ago',
#  '',
#  '',
#  '1 year ago',
#  '',
#  '',
#  '1 year ago (edited)',
#  '',
#  '',
#  '1 year ago',
#  '',
#  '',
#  '7 months ago',
#  '',
#  '',
#  '1 year ago (edited)',
#  '',
#  '',
#  '1 year ago (edited)',
#  '',
#  '',
#  '1 year ago',
#  '',
#  '',
#  '10 months ago',
#  '',
#  '',
#  '1 year ago',
#  '',
#  '',
#  '1 year ago',
#  '',
#  '',
#  '1 year ago',
#  '',
#  '',
#  '6 months ago',
#  '',
#  '',
#  '1 year ago',
#  '',
#  '',
#  '1 year ago',
#  '',
#  '',
#  '1 year ago',
#  '',
#  '',
#  '1 year ago',
#  '',
#  '',
#  '1 year ago',
#  '',
#  '',
#  '1 year ago',
#  '',
#  '',
#  '1 year ago',
#  '',
#  '',
#  '6 months ago',
#  '',
#  '',
#  '1 year ago',
#  '',
#  '',
#  '1 year ago (edited)',
#  '',
#  '',
# ...

# %%
Upvotes = []

start = 0
end = 24

for page in range(start,end):
    upv_tag = driver.find_elements(By.XPATH,'//span[@class="style-scope ytd-comment-engagement-bar"]')
    for i in upv_tag:
        Upvotes.append(i.text)
    
Upvotes
# Out:
# ['6.7K',
#  '4.3K',
#  '6.6K',
#  '330',
#  '3.2K',
#  '9.8K',
#  '1.6K',
#  '828',
#  '3K',
#  '3.6K',
#  '3.4K',
#  '42',
#  '10K',
#  '1.9K',
#  '1.3K',
#  '64',
#  '3.2K',
#  '1.3K',
#  '512',
#  '28',
#  '6.7K',
#  '4.3K',
#  '6.6K',
#  '330',
#  '3.2K',
#  '9.8K',
#  '1.6K',
#  '828',
#  '3K',
#  '3.6K',
#  '3.4K',
#  '42',
#  '10K',
#  '1.9K',
#  '1.3K',
#  '64',
#  '3.2K',
#  '1.3K',
#  '512',
#  '28',
#  '6.7K',
#  '4.3K',
#  '6.6K',
#  '330',
#  '3.2K',
#  '9.8K',
#  '1.6K',
#  '828',
#  '3K',
#  '3.6K',
#  '3.4K',
#  '42',
#  '10K',
#  '1.9K',
#  '1.3K',
#  '64',
#  '3.2K',
#  '1.3K',
#  '512',
#  '28',
#  '6.7K',
#  '4.3K',
#  '6.6K',
#  '330',
#  '3.2K',
#  '9.8K',
#  '1.6K',
#  '828',
#  '3K',
#  '3.6K',
#  '3.4K',
#  '42',
#  '10K',
#  '1.9K',
#  '1.3K',
#  '64',
#  '3.2K',
#  '1.3K',
#  '512',
#  '28',
#  '6.7K',
#  '4.3K',
#  '6.6K',
#  '330',
#  '3.2K',
#  '9.8K',
#  '1.6K',
#  '828',
#  '3K',
#  '3.6K',
#  '3.4K',
#  '42',
#  '10K',
#  '1.9K',
#  '1.3K',
#  '64',
# ...

# %% [markdown]
# HOSTELS IN LONDON

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.keys import Keys
import time

# %%
driver = webdriver.Chrome()

# %%
driver.get(' https://www.hostelworld.com/')

# %%
location = driver.find_element(By.CLASS_NAME,"native-input")
location.send_keys('London')

# %%
optn = driver.find_element(By.XPATH,'/html/body/div[3]/div/div[3]/main/header/div/div[2]/div[1]/div[1]/div/div[1]/div[2]/div/ul/li[2]/button')
optn.click()

# %%
search = driver.find_element(By.XPATH,'/html/body/div[3]/div/div[3]/main/header/div/div[2]/div[1]/div[1]/div/div[5]/button[2]/div')
search.click()

# %%
Web = []

start = 0
end = 1

for page in range(start,end):
    web_tags = driver.find_elements(By.XPATH,'//a[@class="property-card-container horizontal"]')
    for i in web_tags:
        Web.append(i.get_attribute('href'))
    
    next_button = driver.find_elements(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div[1]/div/div[7]/div/button[2]')  

Web
# Out:
# ["https://www.hostelworld.com/pwa/hosteldetails.php/Wombat's%20City%20Hostel%20London/London/88047?from=2024-09-26&to=2024-09-29&guests=2",
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Onefam%20Waterloo/London/39493?from=2024-09-26&to=2024-09-29&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Urbany%20Hostel%20London/London/303427?from=2024-09-26&to=2024-09-29&guests=2',
#  "https://www.hostelworld.com/pwa/hosteldetails.php/St%20Christopher's%20Village%20-%20London%20Bridge/London/502?from=2024-09-26&to=2024-09-29&guests=2",
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Onefam%20Notting%20Hill/London/291433?from=2024-09-26&to=2024-09-29&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Generator%20London/London/510?from=2024-09-26&to=2024-09-29&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Clink261/London/516?from=2024-09-26&to=2024-09-29&guests=2',
# ...

# %%
len(Web)
# Out:
# 30

# %%
Hostel_name = []

for i in Web:
    driver.get(i)
    time.sleep(5)
    
    try:
        hname_tags = driver.find_element(By.XPATH,'//h1[@class="name title-4-bld"]')
        Hostel_name.append(hname_tags.text)     
    except NoSuchElementException: 
        Hostel_name.append('-')
        
Hostel_name
# Out:
# ["Wombat's City Hostel London",
#  'Palmers Lodge - Swiss Cottage',
#  'Onefam Waterloo',
#  'Urbany Hostel London',
#  "St Christopher's Village - London Bridge",
#  'Onefam Notting Hill',
#  'Generator London',
#  'Clink261',
#  'Astor Museum Inn',
#  'NX London Hostel',
#  'Hostelle - women only hostel London',
#  'Safestay London Kensington Holland Park',
#  'Safestay London Elephant & Castle',
#  'Smart Russell Square Hostel',
#  'Queen Elizabeth Chelsea',
#  'Saint James Backpackers',
#  'London Backpackers',
#  'Phoenix Hostel',
#  'Astor Hyde Park',
#  'Smart Hyde Park Inn Hostel',
#  'Astor Victoria',
#  'Kabannas London St Pancras',
#  "St Christopher's Hammersmith",
#  "St Christopher's Camden",
#  'Prime Backpackers Angel',
#  "St Christopher's Greenwich",
#  'Astor Kensington',
#  'Park Villa',
#  'Bell House Hostel',
#  'PubLove @ The White Ferry, Victoria']

# %%
Distance = []

for i in Web:
    driver.get(i)
    time.sleep(5)
    
    try:
        dist_tags = driver.find_element(By.XPATH,'//div[@class="location-snippet-city-center"]')
        Distance.append(dist_tags.text)     
    except NoSuchElementException: 
        Distance.append('-')
        
Distance
# Out:
# ['3.6km from city centre',
#  '6.5km from city centre',
#  '0.7km from city centre',
#  '5.4km from city centre',
#  '1.8km from city centre',
#  '5.5km from city centre',
#  '3km from city centre',
#  '3.2km from city centre',
#  '2.2km from city centre',
#  '6.1km from city centre',
#  '5.1km from city centre',
#  '5.8km from city centre',
#  '1.7km from city centre',
#  '2.6km from city centre',
#  '5.7km from city centre',
#  '5.5km from city centre',
#  '11.9km from city centre',
#  '4.2km from city centre',
#  '4.3km from city centre',
#  '5km from city centre',
#  '1.8km from city centre',
#  '3.3km from city centre',
#  '7.5km from city centre',
#  '4.3km from city centre',
#  '3.6km from city centre',
#  '7.6km from city centre',
#  '4.9km from city centre',
#  '6.3km from city centre',
#  '4.2km from city centre',
#  '2.4km from city centre']

# %%
Ratings = []

for i in Web:
    driver.get(i)
    time.sleep(5)
    
    try:
        rtng_tags = driver.find_element(By.XPATH,'//span[@class="score"]')
        Ratings.append(rtng_tags.text)     
    except NoSuchElementException: 
        Ratings.append('-')
        
Ratings
# Out:
# ['9.3',
#  '8.6',
#  '9.2',
#  '9.6',
#  '7.9',
#  '9.6',
#  '7.0',
#  '8.1',
#  '8.7',
#  '7.3',
#  '8.4',
#  '7.1',
#  '6.9',
#  '7.4',
#  '7.5',
#  '8.0',
#  '8.5',
#  '7.0',
#  '7.7',
#  '7.7',
#  '7.4',
#  '8.1',
#  '7.6',
#  '7.5',
#  '8.8',
#  '7.6',
#  '7.7',
#  '9.0',
#  '6.6',
#  '7.5']

# %%
T_Review = []

for i in Web:
    driver.get(i)
    time.sleep(5)
    
    try:
        trev_tags = driver.find_element(By.XPATH,'//span[@class="num-reviews left-margin"]')
        T_Review.append(trev_tags.text)     
    except NoSuchElementException: 
        T_Review.append('-')
        
T_Review
# Out:
# ['(17023)',
#  '(502)',
#  '(1458)',
#  '(13280)',
#  '(2997)',
#  '(8479)',
#  '(798)',
#  '(9630)',
#  '(2144)',
#  '(263)',
#  '(1983)',
#  '(5446)',
#  '(10359)',
#  '(3876)',
#  '(2017)',
#  '(4676)',
#  '(4889)',
#  '(12438)',
#  '(6903)',
#  '(15207)',
#  '(3092)',
#  '(4513)',
#  '(4224)',
#  '(933)',
#  '(3527)',
#  '(6643)',
#  '(949)',
#  '(243)',
#  '(483)',
#  '(280)']

# %%
O_Review = []

for i in Web:
    driver.get(i)
    time.sleep(5)
    
    try:
        orev_tags = driver.find_element(By.XPATH,'//span[@class="keyword"]')
        O_Review.append(orev_tags.text)     
    except NoSuchElementException: 
        O_Review.append('-')
        
O_Review
# Out:
# ['Superb',
#  'Fabulous',
#  'Superb',
#  'Superb',
#  'Very Good',
#  'Superb',
#  'Very Good',
#  'Fabulous',
#  'Fabulous',
#  'Very Good',
#  'Fabulous',
#  'Very Good',
#  'Good',
#  'Very Good',
#  'Very Good',
#  'Fabulous',
#  'Fabulous',
#  'Very Good',
#  'Very Good',
#  'Very Good',
#  'Very Good',
#  'Fabulous',
#  'Very Good',
#  'Very Good',
#  'Fabulous',
#  'Very Good',
#  'Very Good',
#  'Superb',
#  'Good',
#  'Very Good']

# %%
Privates = []

for i in Web:
    driver.get(i)
    time.sleep(5)
    
    try:
        prvt_tags = driver.find_element(By.XPATH,'//div[@class="body-1-bld"]')
        Privates.append(prvt_tags.text)     
    except NoSuchElementException: 
        Privates.append('-')
        
Privates
# Out:
# ['Rs36384.00',
#  'Rs21435.45',
#  'Rs14838.90',
#  'Rs24835.55',
#  'Rs22399.88',
#  'Rs27559.87',
#  'Rs5161.11',
#  'Rs3837.55',
#  'Rs11559.64',
#  'Rs6712.91',
#  '-',
#  'Rs2367.42',
#  'Rs3494.07',
#  'Rs3393.38',
#  'Rs11076.31',
#  'Rs8577.99',
#  'Rs3401.21',
#  'Rs3509.74',
#  'Rs20631.02',
#  'Rs3149.48',
#  'Rs18908.04',
#  'Rs2979.42',
#  'Rs3676.44',
#  'Rs10495.64',
#  'Rs2446.86',
#  'Rs4146.34',
#  'Rs4974.27',
#  'Rs3468.34',
#  'Rs4438.36',
#  'Rs4550.24']

# %%
Dorms = []

for i in Web:
    driver.get(i)
    time.sleep(5)
    
    try:
        dorm_tags = driver.find_element(By.XPATH,'//p[@class="from-price"]')
        Dorms.append(dorm_tags.text)     
    except NoSuchElementException: 
        Dorms.append('-')
        
Dorms
# Out:
# ['Rs5133.14',
#  'Rs5606.40',
#  'Rs4399.20',
#  'Rs2708.66',
#  'Rs21055.06',
#  'Rs3442.61',
#  'Rs4645.34',
#  'Rs3837.55',
#  'Rs2314.84',
#  'Rs6712.91',
#  '-',
#  'Rs2295.82',
#  'Rs3145.00',
#  'Rs3054.38',
#  'Rs4154.18',
#  'Rs2610.20',
#  'Rs2891.03',
#  'Rs3488.48',
#  'Rs3094.65',
#  'Rs3149.48',
#  'Rs4774.00',
#  'Rs2708.66',
#  'Rs3565.68',
#  'Rs9550.24',
#  'Rs2224.21',
#  'Rs4146.34',
#  'Rs4974.27',
#  'Rs3468.34',
#  'Rs3994.18',
#  'Rs4094.88']

# %%
Facilities = []

for i in Web:
    driver.get(i)
    time.sleep(5)
    
    try:
        fac_tags = driver.find_element(By.XPATH,'//div[@class="facilities snippet"]')
        Facilities.append(fac_tags.text.replace("\n",","))     
    except NoSuchElementException: 
        Facilities.append('-')

Facilities
# Out:
# ['Free City Maps,Free WiFi,Free Internet Access,Free Security Lockers,Bicycle Parking,Meeting Rooms,Adaptors,Luggage Storage',
#  'Free WiFi,Free Internet Access,Bicycle Parking,Adaptors,Luggage Storage,24 Hour Reception,Postal Service,Parking',
#  'Free WiFi,Free Internet Access,Free Security Lockers,Free Luggage Storage,Adaptors,Luggage Storage,24 Hour Reception,Housekeeping',
#  'Free WiFi,Luggage Storage,24 Hour Reception,Wi-Fi,Tea & Coffee Making Facilities,Microwave,Security Lockers,Linen Included',
#  'Free City Maps,Free WiFi,Free Internet Access,Adaptors,Luggage Storage,24 Hour Reception,Housekeeping,Internet access',
#  'Free WiFi,Free Internet Access,Luggage Storage,Tea & Coffee Making Facilities,Self-Catering Facilities,Hot Showers,Linen Included,Flexible NRR',
#  'Free City Maps,Free WiFi,Free Internet Access,Bicycle Parking,Meeting Rooms,Airport Transfers,Luggage Storage,24 Hour Reception',
# ...

# %%
Description = []

for i in Web:
    driver.get(i)
    time.sleep(5)
    
    try:
        desc_tags = driver.find_element(By.XPATH,'//p[@class="text line-clamp"]')
        Description.append(desc_tags.text)     
    except NoSuchElementException: 
        Description.append('-')

Description
# Out:
# ["A safe haven in the middle of the metropolis: We took a traditional brick building with roots dating back to the 1800s and set a new standard for hostel life in the UK.\nWhat was once sailors' accommodation is now a hostel that caters for all the needs of the modern traveller. With great attention to detail, we have created a hostel in London that celebrates the heritage of our historic building.\nThe old oak that once formed part of sturdy ships and churches is now immortalised in our furnishings throughout the house. The beers you drink here will be served on a bar made from 500 year old wood!\n\nOur Wombat's City Hostel is located in the London Borough of Tower Hamlets, right next to the famous Tower Bridge and Tower of London, charming markets, authentic pubs and many other places of historical interest.\nA short walk will take you to trendy Shoreditch with its vibrant street art, the lively nightlife of Hoxton Square and Old Street and finally Brick Lane, which has become one 
# ...

# %%
df = pd.DataFrame({"Hostel Name":Hostel_name,"Distance":Distance,"Ratings":Ratings,"Total Reviews":T_Review,"Overall Reviews":O_Review,"Privates(From Price)":Privates,"Dorms(From Price)":Dorms,"Facilities":Facilities,"Description":Description})
df
# Out:
#                                  Hostel Name                 Distance Ratings  \
# 0                Wombat's City Hostel London   3.6km from city centre     9.3
# 1              Palmers Lodge - Swiss Cottage   6.5km from city centre     8.6
# 2                            Onefam Waterloo   0.7km from city centre     9.2
# 3                       Urbany Hostel London   5.4km from city centre     9.6
# 4   St Christopher's Village - London Bridge   1.8km from city centre     7.9
# 5                        Onefam Notting Hill   5.5km from city centre     9.6
# 6                           Generator London     3km from city centre     7.0
# 7                                   Clink261   3.2km from city centre     8.1
# 8                           Astor Museum Inn   2.2km from city centre     8.7
# 9                           NX London Hostel   6.1km from city centre     7.3
# 10       Hostelle - women only hostel London   5.1km from city centre     8.4
# ...
